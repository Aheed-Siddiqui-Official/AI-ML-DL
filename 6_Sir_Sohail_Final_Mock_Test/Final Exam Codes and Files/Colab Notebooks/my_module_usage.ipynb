# %%
import my_module as m

# %%
dir(m)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'calc',
#  'great',
#  'least',
#  'summation',
#  'table',
#  'temp_conversion']

# %%
m.table(2)
# Out:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20

# %%
m.great([10,70,11,110])
# Out:
# 110

# %%
m.least([10,70,11,110])
# Out:
# 10

# %%
m.summation([10,70,11,110])
# Out:
# 201

# %%
m.temp_conversion(40, "C", "F")
# Out:
# 104.0

# %%
help(m.table)
# Out:
# Help on function table in module my_module:
#
# table(number=2, start=1, end=10)
