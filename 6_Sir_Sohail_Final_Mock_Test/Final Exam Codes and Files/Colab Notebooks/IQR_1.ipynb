# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import linregress
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
df = pd.read_csv("placement.csv")

# %%
df.sample(5)
# Out:
#      cgpa  placement_exam_marks  placed
# 191  6.63                   8.0       0
# 670  7.51                  17.0       1
# 92   6.48                  63.0       0
# 415  6.37                  46.0       1
# 188  5.92                  55.0       1

# %%
import warnings
warnings.filterwarnings("ignore")

def dist2Chart(c2):
  plt.figure(figsize=(16,5))
  plt.subplot(1,2,2)
  sns.distplot(df[c2])
  plt.show()

# %%
sns.histplot(data=df, x="cgpa", kde=True)

plt.show()

# %%
dist2Chart("placement_exam_marks")

# %%
df.head()
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0

# %%
df.shape
# Out:
# (1000, 3)

# %%
df["cgpa"].quantile(0.25)
df["cgpa"].quantile(0.5)
df["cgpa"].quantile(0.75)
# Out:
# np.float64(7.37)

# %%
df["cgpa"].median()
# Out:
# 6.96

# %%
# IQR method
def outlier_remover(df, column):
  q1 = df[column].quantile(0.25)
  q3 = df[column].quantile(0.75)
  IQR = q3-q1
  lower_bound = q1-1.5*IQR
  upper_bound = q3+1.5*IQR
  df = df[(df[column] > lower_bound) & (df[column] < upper_bound)]
  return df

# %%
sns.boxplot(data=df, x=df["cgpa"])
# Out:
# <Axes: xlabel='cgpa'>

# %%
df1 = df.copy()

# %%
sns.boxplot(data=df, x=df["placement_exam_marks"])
# Out:
# <Axes: xlabel='placement_exam_marks'>

# %%
df1 = outlier_remover(df1, "placement_exam_marks")
sns.boxplot(data=df1, x=df1["placement_exam_marks"])
# Out:
# <Axes: xlabel='placement_exam_marks'>

# %%
df1.shape
# Out:
# (985, 3)

# %%
dist2Chart("placement_exam_marks")

# %%
df1.to_csv("placement_new.csv")

# %%
df1.shape
# Out:
# (985, 3)
