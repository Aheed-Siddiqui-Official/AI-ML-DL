# %% [markdown]
# ## Conditions in Python

# %%
marks = float(input("Enter your marks: "))
if marks >= 80:
  grade = "A"
elif marks >= 70:
  grade = "B"
elif marks >= 60:
  grade = "C"
else:
  grade = "F"
print("Your grade is: ", grade)
# Out:
# Enter your marks: 56
# Your grade is:  F

# %%
marks = float(input("Enter your marks: "))

if marks >= 80:
  grade = "A"
elif marks >=70 and marks < 80:
  grade = "B"
elif marks >= 60 and marks < 70:
  grade = "C"
else:
  grade = "F"
print("Your grade is: ", grade)
# Out:
# Enter your marks: 73
# Your grade is:  B

# %%
a = float(input("Enter any number: "))
b = float(input("Enter any number: "))
c = a + b
print(f"Sum of {a} and {b} is {c}.")
# Out:
# Enter any number: 4
# Enter any number: 6
# Sum of 4.0 and 6.0 is 10.0.

# %%
a = float(input("Enter any number: "))
b = float(input("Enter any number: "))
operator = input("Enter an operator '+' or '-': ")
if operator == "+":
  result = a + b
elif operator == "-":
  result = a - b
elif operator == "*":
  result = a * b
elif operator == "/":
  result = a / b
else:
  print("Invalid operator.")
print(f"Result is {result}.")
# Out:
# Enter any number: 3
# Enter any number: 6
# Enter an operator '+' or '-': -
# Result is -3.0.

# %%
Temperature1 = float(input("Enter Temperature in Celcius: "))
Selection = input("Enter Unit, Type 'F' for Fahrenheit and 'C' for Celcius: ")

if Selection in ['C', 'c']:
  Temperature = (Temperature1 * 9/5) + 32
  input_unit = "C"
  output_unit = "F"

elif Selection in ['F', 'f']:
  Temperature = (Temperature1  - 32) * 5/9
  input_unit = "F"
  output_unit = "C"
else:
  Temperature = "Invalid Selection."
  input_unit = ""
  output_unit = ""


print(f"{Temperature1} °{input_unit}→{Temperature} °{output_unit}")
# Out:
# Enter Temperature in Celcius: 0
# Enter Unit, Type 'F' for Fahrenheit and 'C' for Celcius: C
# 0.0 °C→32.0 °F
