# %%
# Question No 01

name = input("Enter your name: ")
course = input("Enter your course name: ")
year = input("Enter your enrolled year: ")
print("Name : ", name, "| ", "Course : ", course, "| ", "Year ", year)
# Out:
# Enter your name: Ali
# Enter your course name: Python
# Enter your enrolled year: 2026
# Name :  Ali |  Course :  Python |  Year  2026

# %%
# Question No 02

name = input("Enter your name: ")
course = input("Enter your course name: ")
year = input("Enter your enrolled year: ")
print(f"Name : {name} | Course : {course} | Year : {year}")
# Out:
# Enter your name: Ali
# Enter your course name: Python
# Enter your enrolled year: 2026
# Name : Ali | Course : Python | Year : 2026

# %%
# Question No 03

variable = int(input("Enter an integer number: "))
print(variable,type(variable))
variable = float(input("Enter a number: "))
print(variable,type(variable))
variable = input("Enter name: ")
print(variable,type(variable))
# Out:
# Enter an integer number: 10
# 10 <class 'int'>
# Enter a number: 10.5
# 10.5 <class 'float'>
# Enter name: Python
# Python <class 'str'>

# %%
# Question No 04

num_1 = float(input("Enter a number: "))
num_2 = float(input("Enter a number: "))
sum = num_1 + num_2
quotient = num_1 // num_2
Remainder = num_1 % num_2

print(f"Sum : {sum}, Floor Division : {quotient}, Remainder : {Remainder}")
# Out:
# Enter a number: 15
# Enter a number: 4
# Sum : 19.0, Floor Division : 3.0, Remainder : 3.0

# %%
# Question No 05

birth_year = int(input("Enter your birth year: "))
current_year = int(input("Enter current year: "))
age = current_year - birth_year

print(f"Your age is {age}.")
# Out:
# Enter your birth year: 2002
# Enter current year: 2026
# Your age is 24.

# %%
# Question No 06

a = int(input("Enter a number: "))
b = int(input("Enter a number: "))
b, a = a, b
print(f"a = {a}, b = {b}")
# Out:
# Enter a number: 5
# Enter a number: 10
# a = 10, b = 5

# %%
# Question No 07

a = int(input("Enter a number: "))
b = int(input("Enter a number: "))
c = a
a = b
b = c
print(f"a = {a}, b = {b}")
# Out:
# Enter a number: 5
# Enter a number: 10
# a = 10, b = 5

# %%
# Question No 08

number = int(input("Enter a number: "))
number += number
print(number)
number *= number
print(number)
# Out:
# Enter a number: 5
# 10
# 100

# %%
# Question No 09

print("Python \n Programming \n  Language")
# Out:
# Python
#  Programming
#   Language

# %%
# Question No 10

word = input("Enter a word: ")

print(f"First Letter : {word[0]}, Last Letter : {word[-1]}, Length of word : {len(word)}")
# Out:
# Enter a word: Python
# First Letter : P, Last Letter : n, Length of word : 6

# %%
# Question No 11:

word = input("Enter a word: ")
half = int(len(word) / 2)
print(f"First Half : {word[0:half]}, Middle : {word[1:len(word)-1]}")
# Out:
# Enter a word: Programming
# First Half : Progr, Middle : rogrammin

# %%
# Question No 12

word = input("Enter a word: ")
print(f"Reverse : {word[::-1]}")
# Out:
# Enter a word: Data
# Reverse : ataD

# %%
# Question No 13

word = input("Enter a word: ")
length = len(word)
print(word[0:length:2])
# Out:
# Enter a word: Python
# Pto

# %%
# Question No 14

str1 = input("Enter a word: ")
str2 = input("Enter a word: ")
if str1 == str2:
  print("Equal")
# Out:
# Enter a word: Python
# Enter a word: Python
# Equal

# %%
# Question No 15

sentence = input("Enter a sentence: ")
word = input("Enter a word: ")

if word in sentence:
  res = "Found"
else:
  res = "Not Found"
print(res)
# Out:
# Enter a sentence: I like Python
# Enter a word: Python
# Found

# %%
# Question No 16
word = input("Enter a word: ")

upper = word.upper()
lower = word.lower()
title = word.title()

print(f"Upper : {upper}, Lower : {lower}, Title : {title}")
# Out:
# Enter a word: Big Data Analytics
# Upper : BIG DATA ANALYTICS, Lower : big data analytics, Title : Big Data Analytics

# %%
# Question No 17

sentence = input("Enter a sentence: ")
old = input("Enter a word: ")
new = input ("ENter a word that you want to replace: ")

if old in sentence:
  new_sentence = sentence.replace(old,new)
  print(new_sentence)
# Out:
# Enter a sentence: I like Java
# Enter a word: Java
# ENter a word that you want to replace: Python
# I like Python

# %%
# Question No 18

string = input("Enter a word: ")
substring = input ("Enter a substring: ")
index = string.find(substring)
print(index)
# Out:
# Enter a word: Big Data Analytics
# Enter a substring: Data
# 4

# %%
# Question No 19

sentence = input("Enter a sentence: ")
print(sentence.split())
# Out:
# Enter a sentence: Programming is fun
# ['Programming', 'is', 'fun']

# %%
# Question No 20

list = ['Python', 'Java', 'C++']
print(list)
# Out:
# ['Python', 'Java', 'C++']

# %%
# Question No 21

list = ['Python', 'Java', 'C++']
print(f"First Element : {list[0]}, Last Element : {list[-1]}")
# Out:
# First Element : Python, Last Element : C++

# %%
# Question No 22

list = ['Python', 'Java']
list.insert(1 ,"C++")
print(list)
# Out:
# ['Python', 'C++', 'Java']

# %%
# Question No 23

list = ['Python', 'Java', 'C++']
list.remove("Java")
print(list)
list.pop()
print(list)
# Out:
# ['Python', 'C++']
# ['Python']

# %%
# Question No 24

list = ['Python', 'C++', 'Java', 'Go']
print(list[1:3])
# Out:
# ['C++', 'Java']

# %%
# Question No 25

list = [25, 5, 11, 9]
list.sort()
print(list)
# Out:
# [5, 9, 11, 25]
