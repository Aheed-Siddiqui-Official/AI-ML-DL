# %%
a = [0, 1, 2, 3, 4]

# %%
import numpy as np

# %%
a = np.array(a)
a
# Out:
# array([0, 1, 2, 3, 4])

# %%
a.dtype
# Out:
# dtype('int64')

# %%
a = np.array([0.4, 1.2, 2.4, 3.6, 4.3])

# %%
a.dtype
# Out:
# dtype('float64')

# %%
type(a)
# Out:
# numpy.ndarray

# %%
c = np.array([20, 1, 2, 3, 5])

# %%
c[0] = 100

# %%
c
# Out:
# array([100,   1,   2,   3,   5])

# %%
c[1:4]
# Out:
# array([1, 2, 3])

# %%
c[3:5] = 300, 400

# %%
c
# Out:
# array([100,   1,   2, 300, 400])

# %%
select = [0, 2, 3]

# %%
d = c[select]
d
# Out:
# array([100,   2, 300])

# %%
c[select] = 1000000

# %%
c
# Out:
# array([1000000,       1, 1000000, 1000000,     400])

# %%
a = np.array([0, 1, 2, 3, 4])

# %%
a.size
# Out:
# 5

# %%
a.ndim
# Out:
# 1

# %%
a.shape
# Out:
# (5,)

# %%
Mean = a.mean()
Mean
# Out:
# np.float64(2.0)

# %%
Median = np.median(a)
Median
# Out:
# np.float64(2.0)

# %%
np.std(a)
# Out:
# np.float64(1.4142135623730951)

# %%
a.max()
# Out:
# np.int64(4)

# %%
a.min()
# Out:
# np.int64(0)

# %%
u = np.array([10, 1, 4])

# %%
v =  np.array([1, 10, 5])

# %%
z = u + v
z
# Out:
# array([11, 11,  9])

# %%
y = 2 * z
y
# Out:
# array([22, 22, 18])

# %%
u * v
# Out:
# array([10, 10, 20])

# %%
u - v
# Out:
# array([ 9, -9, -1])

# %%
u / v
# Out:
# array([10. ,  0.1,  0.8])

# %%
u % v
# Out:
# array([0, 1, 4])

# %%
np.dot(u, v)
# Out:
# np.int64(40)

# %%
u + 1
# Out:
# array([11,  2,  5])

# %%
x = [0, np.pi/2, np.pi]

# %%
x = np.sin(x)
x
# Out:
# array([0.0000000e+00, 1.0000000e+00, 1.2246468e-16])

# %%
array = np.linspace(-2, 2, 5) # (start, stop, number of elements)
array
# Out:
# array([-2., -1.,  0.,  1.,  2.])

# %%
x = np.linspace(0, 2*np.pi, 5)
x
# Out:
# array([0.        , 1.57079633, 3.14159265, 4.71238898, 6.28318531])

# %%
y = np.sin(x)
y
# Out:
# array([ 0.0000000e+00,  1.0000000e+00,  1.2246468e-16, -1.0000000e+00,
#        -2.4492936e-16])

# %%
a = np.array([1, 0])
b = np.array([0, 1])
c = np.dot(a, b)
c
# Out:
# np.int64(0)

# %%
a = np.array([1, 1])
b = np.array([0, 1])
c = np.dot(a, b)
c
# Out:
# np.int64(1)

# %% [markdown]
# # 2 Dim Array

# %%
Ar = np.array([[11, 12, 13],
                  [21, 22, 23],
                  [31, 32, 33]])
Ar
# Out:
# array([[11, 12, 13],
#        [21, 22, 23],
#        [31, 32, 33]])

# %%
Ar.ndim
# Out:
# 2

# %%
Ar.shape
# Out:
# (3, 3)

# %%
Ar.size
# Out:
# 9

# %%
Ar[1, 2]
# Out:
# np.int64(23)

# %%
Ar[1][2]
# Out:
# np.int64(23)

# %%
Ar[0, 0:2]
# Out:
# array([11, 12])

# %%
Ar[1:3, 2]
# Out:
# array([23, 33])

# %%
X = np.array([[1, 0],
              [0, 1]])
Y = np.array([[2, 1],
              [1, 2]])
Z = X + Y
Z
# Out:
# array([[3, 1],
#        [1, 3]])

# %%
X * Y
# Out:
# array([[2, 0],
#        [0, 2]])

# %%
X @ Y
# Out:
# array([[2, 1],
#        [1, 2]])

# %%
A = np.array([[0, 1, 1],
               [1, 0, 1]])
B = np.array([[1, 1],
              [1, 1],
              [-1, 1]])
C = A @ B
C
# Out:
# array([[0, 2],
#        [0, 2]])

# %%
np.dot(A, B)
# Out:
# array([[0, 2],
#        [0, 2]])

# %%
transpose = B.T
transpose
# Out:
# array([[ 1,  1, -1],
#        [ 1,  1,  1]])

# %%
X = np.array([[1, 2],
     [3, 4]])
X.T
# Out:
# array([[1, 3],
#        [2, 4]])
