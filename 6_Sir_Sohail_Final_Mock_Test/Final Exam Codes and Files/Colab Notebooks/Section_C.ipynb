# %% [markdown]
# # Section C

# %% [markdown]
# ## Qno 13 and 14

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
df = pd.read_csv("SalesRecords.csv")

# %%
df.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0       Offline              H  5/28/2010  669165933  6/27/2010        9925
# 1        Online              C  8/22/2012  963881480  9/15/2012        2804
# 2       Offline              L   5/2/2014  341417157   5/8/2014        1779
# 3        Online              C  6/20/2014  514321792   7/5/2014        8102
# 4       Offline              L   2/1/2013  115456712   2/6/2013        5062
#
# ...

# %%
df.shape
# Out:
# (100, 14)

# %% [markdown]
# The dataset has 100 rows and 14 columns.

# %%
df.isnull().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %% [markdown]
# The dataset has no misssing values.

# %%
df.describe()
# Out:
#            Order ID   Units Sold  Unit Price   Unit Cost  Total Revenue  \
# count  1.000000e+02   100.000000  100.000000  100.000000   1.000000e+02
# mean   5.550204e+08  5128.710000  276.761300  191.048000   1.373488e+06
# std    2.606153e+08  2794.484562  235.592241  188.208181   1.460029e+06
# min    1.146066e+08   124.000000    9.330000    6.920000   4.870260e+03
# 25%    3.389225e+08  2836.250000   81.730000   35.840000   2.687212e+05
# 50%    5.577086e+08  5382.500000  179.880000  107.275000   7.523144e+05
# 75%    7.907551e+08  7369.000000  437.200000  263.330000   2.212045e+06
# max    9.940222e+08  9925.000000  668.270000  524.960000   5.997055e+06
#
#          Total Cost  Total Profit
# count  1.000000e+02  1.000000e+02
# mean   9.318057e+05  4.416820e+05
# std    1.083938e+06  4.385379e+05
# min    3.612240e+03  1.258020e+03
# 25%    1.688680e+05  1.214436e+05
# 50%    3.635664e+05  2.907680e+05
# 75%    1.613870e+06  6.358288e+05
# max    4.509794e+06  1.719922e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    object
#  6   Order ID        100 non-null    int64
#  7   Ship Date       100 non-null    object
#  8   Units Sold      100 non-null    int64
#  9   Unit Price      100 non-null    float64
#  10  Unit Cost       100 non-null    float64
#  11  Total Revenue   100 non-null    float64
#  12  Total Cost      100 non-null    float64
#  13  Total Profit    100 non-null    float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 11.1+ KB

# %%
df["Item Type"].value_counts()
# Out:
# Item Type
# Cosmetics          13
# Clothes            13
# Office Supplies    12
# Fruits             10
# Personal Care      10
# Household           9
# Beverages           8
# Cereal              7
# Baby Food           7
# Vegetables          6
# Snacks              3
# Meat                2
# Name: count, dtype: int64

# %% [markdown]
# It is found that the items "Cosmetics" and "Clothes" are popular in this dataset.

# %%
plt.pie(x=df["Item Type"].value_counts(), labels=df["Item Type"].value_counts().index, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7db6ee1fbec0>,
# ...
#  [Text(1.0095300937030698, 0.43686266710245625, 'Cosmetics'),
#   Text(0.3726116893204676, 1.0349688541119233, 'Clothes'),
#   Text(-0.4683573238698025, 0.9953097091747458, 'Office Supplies'),
#   Text(-0.9953098264249074, 0.4683570747005119, 'Fruits'),
#   Text(-1.0805159911007414, -0.20611936584315108, 'Personal Care'),
#   Text(-0.7778173279449521, -0.7778175906654303, 'Household'),
#   Text(-0.273559480278046, -1.0654413220586132, 'Beverages'),
#   Text(0.2399576744876166, -1.0735084137790887, 'Cereal'),
#   Text(0.6741971740219129, -0.8691709673826357, 'Baby Food'),
#   Text(0.9639373322155872, -0.5299290703113927, 'Vegetables'),
#   Text(1.0735083441753086, -0.23995798587666856, 'Snacks'),
#   Text(1.0978293786450977, -0.06906993111129502, 'Meat')],
#  [Text(0.5506527783834925, 0.23828872751043065, '13.0%'),
#   Text(0.20324273962934594, 0.5645284658792308, '13.0%'),
#   Text(-0.2554676312017104, 0.5428962050044067, '12.0%'),
# ...

# %%
col = ["Total Revenue"	,"Total Profit"]

# %%
for x in col:
  plt.figure(figsize=(8, 6))
  sns.histplot(x=df[x])
  plt.title(f'Distribution of {x}')
  plt.xlabel(x)
  plt.ylabel('Frequency')
  plt.show()

# %% [markdown]
# In Total Profit column the mean value is 4.416820e+05 with standard deviation of 4.385379e+05.
# In Total Revenue column the mean value is 1.373488e+06 with standard deviation of 1.460029e+06.
# And Both columns are right skewed.

# %%
profit_by_item_type = df.groupby('Item Type')['Total Profit'].sum().reset_index()
display(profit_by_item_type)
# Out:
#           Item Type  Total Profit
# 0         Baby Food    3886643.70
# 1         Beverages     888047.28
# 2            Cereal    2292443.43
# 3           Clothes    5233334.40
# 4         Cosmetics   14556048.66
# 5            Fruits     120495.18
# 6         Household    7412605.71
# 7              Meat     610610.00
# 8   Office Supplies    5929583.75
# 9     Personal Care    1220622.48
# 10           Snacks     751944.18
# 11       Vegetables    1265819.63

# %%
profit_by_item_type["Total Profit"].max()
# Out:
# 14556048.66

# %%
profit_by_item_type["Total Profit"].min()
# Out:
# 120495.18

# %% [markdown]
# The more profit is generated from Cosmetics. While less profit is generated from Fruits.
