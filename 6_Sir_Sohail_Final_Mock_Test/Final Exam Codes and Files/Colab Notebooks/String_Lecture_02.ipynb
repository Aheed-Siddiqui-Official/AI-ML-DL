# %% [markdown]
# ## String Operation

# %% [markdown]
# ## Indexing

# %%
name = "aliyan"
name[-1]
# Out:
# 'n'

# %%
name[0]
# Out:
# 'a'

# %%
name = "Syed Alyan Ali Hashmi"
name[0:len(name):2]
# Out:
# 'Se la l ahi'

# %%
name[::]
# Out:
# 'Syed Alyan Ali Hashmi'

# %%
name[-2:-6]
# Out:
# ''

# %%
name[1::2]
# Out:
# 'ydAynAiHsm'

# %%
name[-len(name):-1:1]
# Out:
# 'Syed Alyan Ali Hashm'

# %%
name[::-1]
# Out:
# 'imhsaH ilA naylA deyS'

# %% [markdown]
# ## Slicing

# %%
name = "Big Data Analytics"
name[4:6]
# Out:
# 'Da'

# %%
name[-14:-12:1]
# Out:
# 'Da'

# %%
name[0:15:2]
# Out:
# 'BgDt nlt'

# %%
name[-18:-3:2]
# Out:
# 'BgDt nlt'

# %%
name[:3]
# Out:
# 'Big'

# %%
name[:-15]
# Out:
# 'Big'

# %%
name[0:3]
# Out:
# 'Big'

# %% [markdown]
# ##Membership Operator

# %%
Name1 = " Data"
Name1 in name
# Out:
# True

# %% [markdown]
# ## Other String Functions

# %%
name.upper()
# Out:
# 'BIG DATA ANALYTICS'

# %%
name.lower()
# Out:
# 'big data analytics'

# %%
name.replace("Analytics", "tools")
# Out:
# 'Big Data tools'

# %%
name.find("Analytics")
# Out:
# 9

# %%
name.find("tools") # if not in string will return "-1"
# Out:
# -1

# %%
len(name)
# Out:
# 18
