# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("SalesRecords.csv")
df.head(3)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_10883/3921686899.py in <cell line: 0>()
# ----> 1 df = pd.read_csv("SalesRecords.csv")
#       2 df.head(3)
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
df.shape
# Out:
# (100, 14)

# %%
df.size
# Out:
# 1400

# %%
df.dtypes
# Out:
# Region             object
# Country            object
# Item Type          object
# Sales Channel      object
# Order Priority     object
# Order Date         object
# Order ID            int64
# Ship Date          object
# Units Sold          int64
# Unit Price        float64
# Unit Cost         float64
# Total Revenue     float64
# Total Cost        float64
# Total Profit      float64
# dtype: object

# %%
df.describe()
# Out:
#            Order ID   Units Sold  Unit Price   Unit Cost  Total Revenue  \
# count  1.000000e+02   100.000000  100.000000  100.000000   1.000000e+02
# mean   5.550204e+08  5128.710000  276.761300  191.048000   1.373488e+06
# std    2.606153e+08  2794.484562  235.592241  188.208181   1.460029e+06
# min    1.146066e+08   124.000000    9.330000    6.920000   4.870260e+03
# 25%    3.389225e+08  2836.250000   81.730000   35.840000   2.687212e+05
# 50%    5.577086e+08  5382.500000  179.880000  107.275000   7.523144e+05
# 75%    7.907551e+08  7369.000000  437.200000  263.330000   2.212045e+06
# max    9.940222e+08  9925.000000  668.270000  524.960000   5.997055e+06
#
#          Total Cost  Total Profit
# count  1.000000e+02  1.000000e+02
# mean   9.318057e+05  4.416820e+05
# std    1.083938e+06  4.385379e+05
# min    3.612240e+03  1.258020e+03
# 25%    1.688680e+05  1.214436e+05
# 50%    3.635664e+05  2.907680e+05
# 75%    1.613870e+06  6.358288e+05
# max    4.509794e+06  1.719922e+06

# %%
df["Region"].describe()
# Out:
# count                    100
# unique                     7
# top       Sub-Saharan Africa
# freq                      36
# Name: Region, dtype: object

# %%
df["Region"].value_counts()
# Out:
# Region
# Sub-Saharan Africa                   36
# Europe                               22
# Australia and Oceania                11
# Asia                                 11
# Middle East and North Africa         10
# Central America and the Caribbean     7
# North America                         3
# Name: count, dtype: int64

# %%
df["Region"].value_counts(normalize=True)
# Out:
# Region
# Sub-Saharan Africa                   0.36
# Europe                               0.22
# Australia and Oceania                0.11
# Asia                                 0.11
# Middle East and North Africa         0.10
# Central America and the Caribbean    0.07
# North America                        0.03
# Name: proportion, dtype: float64

# %%
df["Region"].unique()
# Out:
# array(['Australia and Oceania', 'Central America and the Caribbean',
#        'Europe', 'Sub-Saharan Africa', 'Asia',
#        'Middle East and North Africa', 'North America'], dtype=object)

# %%
df["Region"].nunique()
# Out:
# 7

# %%
pd.crosstab(df["Region"], df["Item Type"])
# Out:
# Item Type                          Baby Food  Beverages  Cereal  Clothes  \
# Region
# Asia                                       0          0       0        2
# Australia and Oceania                      2          2       1        1
# Central America and the Caribbean          0          1       1        1
# Europe                                     4          2       0        3
# Middle East and North Africa               0          0       1        2
# North America                              0          0       0        0
# Sub-Saharan Africa                         1          3       4        4
#
# Item Type                          Cosmetics  Fruits  Household  Meat  \
# Region
# Asia                                       1       1          2     0
# Australia and Oceania                      1       2          0     1
# Central America and the Caribbean          1       0          1     0
# Europe                                     5       0          2     0
# ...

# %%
df["Unit Price"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["Region"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Region'>

# %%
df1 = pd.read_csv("emp.csv")

# %%
df1.head()
# Out:
#    empno   ename        job     mgr    hiredate   sal    comm  deptno
# 0   7839    KING  PRESIDENT     NaN  11/17/2001  5000     NaN      10
# 1   7698   BLAKE    MANAGER  7839.0  05/01/2001  2850     NaN      30
# 2   7782   CLARK    MANAGER  7839.0  06/09/2001  2450     NaN      10
# 3   7566   JONES    MANAGER  7839.0  04/02/2001  2975     NaN      20
# 4   7654  MARTIN   SALESMAN  7698.0  09/28/2001  1250  1400.0      30

# %%
df1.shape
# Out:
# (14, 8)

# %%
df1.columns
# Out:
# Index(['empno', 'ename', 'job', 'mgr', 'hiredate', 'sal', 'comm', 'deptno'], dtype='object')

# %%
len(df1)
# Out:
# 14

# %%
df1.sample(4)
# Out:
#     empno   ename        job     mgr    hiredate   sal    comm  deptno
# 9    7902    FORD    ANALYST  7566.0  02/03/2001  3000     NaN      20
# 4    7654  MARTIN   SALESMAN  7698.0  09/28/2001  1250  1400.0      30
# 10   7369   SMITH      CLERK  7902.0  12/17/2000   800     NaN      20
# 0    7839    KING  PRESIDENT     NaN  11/17/2001  5000     NaN      10

# %%
df1[["empno", "ename", "sal"]].head()
# Out:
#    empno   ename   sal
# 0   7839    KING  5000
# 1   7698   BLAKE  2850
# 2   7782   CLARK  2450
# 3   7566   JONES  2975
# 4   7654  MARTIN  1250

# %%
df1.sort_values(by="sal", ascending=False)
# Out:
#     empno   ename        job     mgr    hiredate   sal    comm  deptno
# 0    7839    KING  PRESIDENT     NaN  11/17/2001  5000     NaN      10
# 9    7902    FORD    ANALYST  7566.0  02/03/2001  3000     NaN      20
# 11   7788   SCOTT    ANALYST  7566.0  04/19/2007  3000     NaN      20
# 3    7566   JONES    MANAGER  7839.0  04/02/2001  2975     NaN      20
# 1    7698   BLAKE    MANAGER  7839.0  05/01/2001  2850     NaN      30
# 2    7782   CLARK    MANAGER  7839.0  06/09/2001  2450     NaN      10
# 5    7499   ALLEN   SALESMAN  7698.0  02/20/2001  1600   300.0      30
# 6    7844  TURNER   SALESMAN  7698.0  09/08/2001  1500     0.0      30
# 13   7934  MILLER      CLERK  7782.0  01/23/2002  1300     NaN      10
# 4    7654  MARTIN   SALESMAN  7698.0  09/28/2001  1250  1400.0      30
# 8    7521    WARD   SALESMAN  7698.0  02/22/2001  1250   500.0      30
# 12   7876   ADAMS      CLERK  7788.0  05/23/2007  1100     NaN      20
# ...

# %%
df1.rename(columns= {"sal":"Salary", "ename":"Employee"})
# Out:
#     empno Employee        job     mgr    hiredate  Salary    comm  deptno
# 0    7839     KING  PRESIDENT     NaN  11/17/2001    5000     NaN      10
# 1    7698    BLAKE    MANAGER  7839.0  05/01/2001    2850     NaN      30
# 2    7782    CLARK    MANAGER  7839.0  06/09/2001    2450     NaN      10
# 3    7566    JONES    MANAGER  7839.0  04/02/2001    2975     NaN      20
# 4    7654   MARTIN   SALESMAN  7698.0  09/28/2001    1250  1400.0      30
# 5    7499    ALLEN   SALESMAN  7698.0  02/20/2001    1600   300.0      30
# 6    7844   TURNER   SALESMAN  7698.0  09/08/2001    1500     0.0      30
# 7    7900    JAMES      CLERK  7698.0  12/03/2001     950     NaN      30
# 8    7521     WARD   SALESMAN  7698.0  02/22/2001    1250   500.0      30
# 9    7902     FORD    ANALYST  7566.0  02/03/2001    3000     NaN      20
# 10   7369    SMITH      CLERK  7902.0  12/17/2000     800     NaN      20
# 11   7788    SCOTT    ANALYST  7566.0  04/19/2007    3000     NaN      20
# ...

# %%
df2 = df1.copy()

# %%
df2["Annual Salary"] = df2["sal"] * 12
df2.head()
# Out:
#    empno   ename        job     mgr    hiredate   sal    comm  deptno  \
# 0   7839    KING  PRESIDENT     NaN  11/17/2001  5000     NaN      10
# 1   7698   BLAKE    MANAGER  7839.0  05/01/2001  2850     NaN      30
# 2   7782   CLARK    MANAGER  7839.0  06/09/2001  2450     NaN      10
# 3   7566   JONES    MANAGER  7839.0  04/02/2001  2975     NaN      20
# 4   7654  MARTIN   SALESMAN  7698.0  09/28/2001  1250  1400.0      30
#
#    Annual Salary
# 0          60000
# 1          34200
# 2          29400
# 3          35700
# 4          15000

# %%
df1.head()
# Out:
#    empno   ename        job     mgr    hiredate   sal    comm  deptno
# 0   7839    KING  PRESIDENT     NaN  11/17/2001  5000     NaN      10
# 1   7698   BLAKE    MANAGER  7839.0  05/01/2001  2850     NaN      30
# 2   7782   CLARK    MANAGER  7839.0  06/09/2001  2450     NaN      10
# 3   7566   JONES    MANAGER  7839.0  04/02/2001  2975     NaN      20
# 4   7654  MARTIN   SALESMAN  7698.0  09/28/2001  1250  1400.0      30

# %%
df2.head()
# Out:
#    empno   ename        job     mgr    hiredate   sal    comm  deptno  \
# 0   7839    KING  PRESIDENT     NaN  11/17/2001  5000     NaN      10
# 1   7698   BLAKE    MANAGER  7839.0  05/01/2001  2850     NaN      30
# 2   7782   CLARK    MANAGER  7839.0  06/09/2001  2450     NaN      10
# 3   7566   JONES    MANAGER  7839.0  04/02/2001  2975     NaN      20
# 4   7654  MARTIN   SALESMAN  7698.0  09/28/2001  1250  1400.0      30
#
#    Annual Salary
# 0          60000
# 1          34200
# 2          29400
# 3          35700
# 4          15000

# %%
df2.head()
# Out:
#    empno   ename        job     mgr    hiredate   sal    comm  deptno  \
# 0   7839    KING  PRESIDENT     NaN  11/17/2001  5000     NaN      10
# 1   7698   BLAKE    MANAGER  7839.0  05/01/2001  2850     NaN      30
# 2   7782   CLARK    MANAGER  7839.0  06/09/2001  2450     NaN      10
# 3   7566   JONES    MANAGER  7839.0  04/02/2001  2975     NaN      20
# 4   7654  MARTIN   SALESMAN  7698.0  09/28/2001  1250  1400.0      30
#
#    Annual Salary
# 0          60000
# 1          34200
# 2          29400
# 3          35700
# 4          15000

# %%
df2[(df2["deptno"]==10) | (df2["sal"] > 2000)]
# Out:
#     empno   ename        job     mgr    hiredate   sal  comm  deptno  \
# 0    7839    KING  PRESIDENT     NaN  11/17/2001  5000   NaN      10
# 1    7698   BLAKE    MANAGER  7839.0  05/01/2001  2850   NaN      30
# 2    7782   CLARK    MANAGER  7839.0  06/09/2001  2450   NaN      10
# 3    7566   JONES    MANAGER  7839.0  04/02/2001  2975   NaN      20
# 9    7902    FORD    ANALYST  7566.0  02/03/2001  3000   NaN      20
# 11   7788   SCOTT    ANALYST  7566.0  04/19/2007  3000   NaN      20
# 13   7934  MILLER      CLERK  7782.0  01/23/2002  1300   NaN      10
#
#     Annual Salary
# 0           60000
# 1           34200
# 2           29400
# 3           35700
# 9           36000
# 11          36000
# 13          15600

# %%
df2[(df2["sal"]>=1000) & (df2["sal"] <= 3000)]
# Out:
#     empno   ename       job     mgr    hiredate   sal    comm  deptno  \
# 1    7698   BLAKE   MANAGER  7839.0  05/01/2001  2850     NaN      30
# 2    7782   CLARK   MANAGER  7839.0  06/09/2001  2450     NaN      10
# 3    7566   JONES   MANAGER  7839.0  04/02/2001  2975     NaN      20
# 4    7654  MARTIN  SALESMAN  7698.0  09/28/2001  1250  1400.0      30
# 5    7499   ALLEN  SALESMAN  7698.0  02/20/2001  1600   300.0      30
# 6    7844  TURNER  SALESMAN  7698.0  09/08/2001  1500     0.0      30
# 8    7521    WARD  SALESMAN  7698.0  02/22/2001  1250   500.0      30
# 9    7902    FORD   ANALYST  7566.0  02/03/2001  3000     NaN      20
# 11   7788   SCOTT   ANALYST  7566.0  04/19/2007  3000     NaN      20
# 12   7876   ADAMS     CLERK  7788.0  05/23/2007  1100     NaN      20
# 13   7934  MILLER     CLERK  7782.0  01/23/2002  1300     NaN      10
#
#     Annual Salary
# 1           34200
# 2           29400
# 3           35700
# 4           15000
# 5           19200
# ...

# %%
df2[df2["ename"].str.endswith("N")]
# Out:
#    empno   ename       job     mgr    hiredate   sal    comm  deptno  \
# 4   7654  MARTIN  SALESMAN  7698.0  09/28/2001  1250  1400.0      30
# 5   7499   ALLEN  SALESMAN  7698.0  02/20/2001  1600   300.0      30
#
#    Annual Salary
# 4          15000
# 5          19200

# %%
df2[df2["ename"].str.startswith("A")]
# Out:
#     empno  ename       job     mgr    hiredate   sal   comm  deptno  \
# 5    7499  ALLEN  SALESMAN  7698.0  02/20/2001  1600  300.0      30
# 12   7876  ADAMS     CLERK  7788.0  05/23/2007  1100    NaN      20
#
#     Annual Salary
# 5           19200
# 12          13200

# %%
df2[(df2["ename"].str.startswith("A")) & (df2["ename"].str.endswith("N"))]
# Out:
#    empno  ename       job     mgr    hiredate   sal   comm  deptno  \
# 5   7499  ALLEN  SALESMAN  7698.0  02/20/2001  1600  300.0      30
#
#    Annual Salary
# 5          19200

# %%
df2[df2["ename"].str.contains("A")]
# Out:
#     empno   ename       job     mgr    hiredate   sal    comm  deptno  \
# 1    7698   BLAKE   MANAGER  7839.0  05/01/2001  2850     NaN      30
# 2    7782   CLARK   MANAGER  7839.0  06/09/2001  2450     NaN      10
# 4    7654  MARTIN  SALESMAN  7698.0  09/28/2001  1250  1400.0      30
# 5    7499   ALLEN  SALESMAN  7698.0  02/20/2001  1600   300.0      30
# 7    7900   JAMES     CLERK  7698.0  12/03/2001   950     NaN      30
# 8    7521    WARD  SALESMAN  7698.0  02/22/2001  1250   500.0      30
# 12   7876   ADAMS     CLERK  7788.0  05/23/2007  1100     NaN      20
#
#     Annual Salary
# 1           34200
# 2           29400
# 4           15000
# 5           19200
# 7           11400
# 8           15000
# 12          13200

# %%
df2.agg(TotalEmp = ("empno", "count"), AvgSal = ("sal", "mean"), Sumsal = ("sal", "sum"))
# Out:
#           empno           sal
# TotalEmp   14.0           NaN
# AvgSal      NaN   2073.214286
# Sumsal      NaN  29025.000000

# %%
df2.agg(TotalEmp = ("empno", "count"), AvgSal = ("sal", "mean"), Sumsal = ("sal", "sum")).T
# Out:
#        TotalEmp       AvgSal   Sumsal
# empno      14.0          NaN      NaN
# sal         NaN  2073.214286  29025.0

# %%
df2.groupby("deptno").agg(TotalEmp = ("empno", "count"), AvgSal = ("sal", "mean"), Sumsal = ("sal", "sum"))
# Out:
#         TotalEmp       AvgSal  Sumsal
# deptno
# 10             3  2916.666667    8750
# 20             5  2175.000000   10875
# 30             6  1566.666667    9400

# %%
df3 = pd.read_csv("emp.csv")
df3.head()
# Out:
#    empno   ename        job     mgr    hiredate   sal    comm  deptno
# 0   7839    KING  PRESIDENT     NaN  11/17/2001  5000     NaN      10
# 1   7698   BLAKE    MANAGER  7839.0  05/01/2001  2850     NaN      30
# 2   7782   CLARK    MANAGER  7839.0  06/09/2001  2450     NaN      10
# 3   7566   JONES    MANAGER  7839.0  04/02/2001  2975     NaN      20
# 4   7654  MARTIN   SALESMAN  7698.0  09/28/2001  1250  1400.0      30

# %%
df4 = pd.read_csv("dept.csv")
df4.head()
# Out:
#    deptno       dname       loc
# 0      10  ACCOUNTING  NEW YORK
# 1      20    RESEARCH    DALLAS
# 2      30       SALES   CHICAGO
# 3      40  OPERATIONS    BOSTON

# %%
merge = pd.merge(df3, df4)
merge.head()
# Out:
#    empno   ename        job     mgr    hiredate   sal    comm  deptno  \
# 0   7839    KING  PRESIDENT     NaN  11/17/2001  5000     NaN      10
# 1   7698   BLAKE    MANAGER  7839.0  05/01/2001  2850     NaN      30
# 2   7782   CLARK    MANAGER  7839.0  06/09/2001  2450     NaN      10
# 3   7566   JONES    MANAGER  7839.0  04/02/2001  2975     NaN      20
# 4   7654  MARTIN   SALESMAN  7698.0  09/28/2001  1250  1400.0      30
#
#         dname       loc
# 0  ACCOUNTING  NEW YORK
# 1       SALES   CHICAGO
# 2  ACCOUNTING  NEW YORK
# 3    RESEARCH    DALLAS
# 4       SALES   CHICAGO

# %%
pd.merge(df3, df4, on="deptno", how="inner").head()
# Out:
#    empno   ename        job     mgr    hiredate   sal    comm  deptno  \
# 0   7839    KING  PRESIDENT     NaN  11/17/2001  5000     NaN      10
# 1   7698   BLAKE    MANAGER  7839.0  05/01/2001  2850     NaN      30
# 2   7782   CLARK    MANAGER  7839.0  06/09/2001  2450     NaN      10
# 3   7566   JONES    MANAGER  7839.0  04/02/2001  2975     NaN      20
# 4   7654  MARTIN   SALESMAN  7698.0  09/28/2001  1250  1400.0      30
#
#         dname       loc
# 0  ACCOUNTING  NEW YORK
# 1       SALES   CHICAGO
# 2  ACCOUNTING  NEW YORK
# 3    RESEARCH    DALLAS
# 4       SALES   CHICAGO

# %%
pd.merge(df3, df4, left_on="deptno", right_on="deptno", how="inner").head() # this is used if both have not same name like ""deptno & depno""
# Out:
#    empno   ename        job     mgr    hiredate   sal    comm  deptno  \
# 0   7839    KING  PRESIDENT     NaN  11/17/2001  5000     NaN      10
# 1   7698   BLAKE    MANAGER  7839.0  05/01/2001  2850     NaN      30
# 2   7782   CLARK    MANAGER  7839.0  06/09/2001  2450     NaN      10
# 3   7566   JONES    MANAGER  7839.0  04/02/2001  2975     NaN      20
# 4   7654  MARTIN   SALESMAN  7698.0  09/28/2001  1250  1400.0      30
#
#         dname       loc
# 0  ACCOUNTING  NEW YORK
# 1       SALES   CHICAGO
# 2  ACCOUNTING  NEW YORK
# 3    RESEARCH    DALLAS
# 4       SALES   CHICAGO

# %%
pd.merge(df3, df4, on="deptno", how="right")
# Out:
#      empno   ename        job     mgr    hiredate     sal    comm  deptno  \
# 0   7839.0    KING  PRESIDENT     NaN  11/17/2001  5000.0     NaN      10
# 1   7782.0   CLARK    MANAGER  7839.0  06/09/2001  2450.0     NaN      10
# 2   7934.0  MILLER      CLERK  7782.0  01/23/2002  1300.0     NaN      10
# 3   7566.0   JONES    MANAGER  7839.0  04/02/2001  2975.0     NaN      20
# 4   7902.0    FORD    ANALYST  7566.0  02/03/2001  3000.0     NaN      20
# 5   7369.0   SMITH      CLERK  7902.0  12/17/2000   800.0     NaN      20
# 6   7788.0   SCOTT    ANALYST  7566.0  04/19/2007  3000.0     NaN      20
# 7   7876.0   ADAMS      CLERK  7788.0  05/23/2007  1100.0     NaN      20
# 8   7698.0   BLAKE    MANAGER  7839.0  05/01/2001  2850.0     NaN      30
# 9   7654.0  MARTIN   SALESMAN  7698.0  09/28/2001  1250.0  1400.0      30
# 10  7499.0   ALLEN   SALESMAN  7698.0  02/20/2001  1600.0   300.0      30
# 11  7844.0  TURNER   SALESMAN  7698.0  09/08/2001  1500.0     0.0      30
# ...

# %%
pd.merge(df3, df4, on="deptno", how="outer", indicator=True)
# Out:
#      empno   ename        job     mgr    hiredate     sal    comm  deptno  \
# 0   7839.0    KING  PRESIDENT     NaN  11/17/2001  5000.0     NaN      10
# 1   7782.0   CLARK    MANAGER  7839.0  06/09/2001  2450.0     NaN      10
# 2   7934.0  MILLER      CLERK  7782.0  01/23/2002  1300.0     NaN      10
# 3   7566.0   JONES    MANAGER  7839.0  04/02/2001  2975.0     NaN      20
# 4   7902.0    FORD    ANALYST  7566.0  02/03/2001  3000.0     NaN      20
# 5   7369.0   SMITH      CLERK  7902.0  12/17/2000   800.0     NaN      20
# 6   7788.0   SCOTT    ANALYST  7566.0  04/19/2007  3000.0     NaN      20
# 7   7876.0   ADAMS      CLERK  7788.0  05/23/2007  1100.0     NaN      20
# 8   7698.0   BLAKE    MANAGER  7839.0  05/01/2001  2850.0     NaN      30
# 9   7654.0  MARTIN   SALESMAN  7698.0  09/28/2001  1250.0  1400.0      30
# 10  7499.0   ALLEN   SALESMAN  7698.0  02/20/2001  1600.0   300.0      30
# 11  7844.0  TURNER   SALESMAN  7698.0  09/08/2001  1500.0     0.0      30
# ...

# %%
df2[df2["deptno"]==20]
# Out:
#     empno  ename      job     mgr    hiredate   sal  comm  deptno  \
# 3    7566  JONES  MANAGER  7839.0  04/02/2001  2975   NaN      20
# 9    7902   FORD  ANALYST  7566.0  02/03/2001  3000   NaN      20
# 10   7369  SMITH    CLERK  7902.0  12/17/2000   800   NaN      20
# 11   7788  SCOTT  ANALYST  7566.0  04/19/2007  3000   NaN      20
# 12   7876  ADAMS    CLERK  7788.0  05/23/2007  1100   NaN      20
#
#     Annual Salary
# 3           35700
# 9           36000
# 10           9600
# 11          36000
# 12          13200

# %%
df2[df2["deptno"]==20]["ename"]
# Out:
# 3     JONES
# 9      FORD
# 10    SMITH
# 11    SCOTT
# 12    ADAMS
# Name: ename, dtype: object
