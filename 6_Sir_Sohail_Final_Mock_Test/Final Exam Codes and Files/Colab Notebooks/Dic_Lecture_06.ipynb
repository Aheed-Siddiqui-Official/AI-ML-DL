# %% [markdown]
# ## Dictionaries

# %%
D1 = {"name" : "Ali", "age" : "23", "city" : "Karachi"}
D1
# Out:
# {'name': 'Ali', 'age': '23', 'city': 'Karachi'}

# %%
len(D1)
# Out:
# 3

# %%
D1["name"]
# Out:
# 'Ali'

# %%
D1.items()
# Out:
# dict_items([('name', 'Ali'), ('age', '23'), ('city', 'Karachi')])

# %%
D1.keys()
# Out:
# dict_keys(['name', 'age', 'city'])

# %%
D1.values()
# Out:
# dict_values(['Ali', '23', 'Karachi'])

# %%
D1["job"] = "Engineer"

# %%
D1
# Out:
# {'name': 'Ali', 'age': '23', 'city': 'Karachi', 'job': 'Engineer'}

# %% [markdown]
# # Update

# %%
D1["age"] = 31
D1
# Out:
# {'name': 'Ali', 'age': 31, 'city': 'Karachi', 'job': 'Engineer'}

# %%
del D1["age"]
D1
# Out:
# {'name': 'Ali', 'city': 'Karachi', 'job': 'Engineer'}

# %%
D1.pop("job")
D1
# Out:
# {'name': 'Ali', 'city': 'Karachi'}

# %%
D1["age"] = 31
D1
# Out:
# {'name': 'Ali', 'city': 'Karachi', 'age': 31}

# %%
D1.popitem()
D1
# Out:
# {'name': 'Ali', 'city': 'Karachi'}

# %%
D1.clear()
D1
# Out:
# {}

# %%
D1 = {'name': 'Ali', 'age': '23', 'city': 'Karachi', 'job': 'Engineer'}

# %%
for i in D1:
  print(i)
# Out:
# name
# age
# city
# job

# %%
for i in D1.values():
  print(i)
# Out:
# Ali
# 23
# Karachi
# Engineer

# %%
for key, value in D1.items():
  print(key, end = "\t")
  print(value)
# Out:
# name	Ali
# age	23
# city	Karachi
# job	Engineer

# %%
"Name" in D1
# Out:
# False

# %%
"name" in D1
# Out:
# True

# %%
"Ali" in D1["name"]
# Out:
# True

# %%
D3 = {"name" : "Ali", "age" : 30}
D4 = {"city" : "Karachi", "Country" : "USA"}

# %%
D3.update(D4)

# %%
D3
# Out:
# {'name': 'Ali', 'age': 30, 'city': 'Karachi', 'Country': 'USA'}

# %%
D5 = {"Name" : ["Ali", "Sara", "Ford"], "Age" : [20, 31, 17]}
D5
# Out:
# {'Name': ['Ali', 'Sara', 'Ford'], 'Age': [20, 31, 17]}

# %% [markdown]
# # Nested Dictionaries

# %%
students = {
    "Alice" : {"age" : 20, "grade" : "A"},
    "Bob" : {"age" : 22, "grade" : "B"}
}

# %%
students["Alice"]["grade"]
# Out:
# 'A'
