# %%
import sys
import numpy as np
print(sys.version)
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %% [markdown]
# ## Print Method()

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Hello", "World", 2)
# Out:
# Hello World 2

# %%
msg = "Hello Aliyan!"
type(msg)
# Out:
# str

# %%
type(3)
# Out:
# int

# %%
type(5.)
# Out:
# float

# %%
print("Number "+5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-935984762.py in <cell line: 0>()
# ----> 1 print("Number "+5)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print("Number ", 5)
# Out:
# Number  5

# %%
a = 1
b = 2
sum = a + b
print("a = ",a, "b = ",b)
print("The sum of 'a' and 'b' is", sum)
# Out:
# a =  1 b =  2
# The sum of 'a' and 'b' is 3

# %% [markdown]
# ## Area of Rectagle

# %%
W = 2
L = 3
Area = W * L
print("Given Inputs, W: width", W, "L: Length", L, ":", "Output: ", "The Area of Rectangle is", Area, ".")
# Out:
# Given Inputs, W: width 2 L: Length 3 : Output:  The Area of Rectangle is 6 .

# %%
W = 2
L = 3
Area = W * L
print(f"Given Inputs: Width: {W}, Length: {L}")
print(f"The area of rectangle is {Area}.")
# Out:
# Given Inputs: Width: 2, Length: 3
# The area of rectangle is 6.

# %%
print(f"Given Inputs, W: width: {W}, L: Length: {L}; Output: The Area of Rectangle is: {Area}.")
# Out:
# Given Inputs, W: width: 2, L: Length: 3; Output: The Area of Rectangle is: 6.

# %%
print("Hello", "World", 2, sep = "-")
# Out:
# Hello-World-2

# %%
print("Hello", end = "-")
print("World", end = "-")
print("3rd")
print("4th")
# Out:
# Hello-World-3rd
# 4th

# %% [markdown]
# ## Boxing

# %%
a,b = 4, 5
print(f"a: {a}, b: {b}")
# Out:
# a: 4, b: 5

# %% [markdown]
# ## Swaping

# %%
b,a = a, b

# %%
print(f"a: {a}, b: {b}")
# Out:
# a: 5, b: 4

# %% [markdown]
# ## Type Casting

# %%
a = int(input("Enter 1st value: "))
b= int(input("Enter 2nd value: "))
c = a + b
print(f"The sum of {a} & {b} is {c}.")
# Out:
# Enter 1st value: 5
# Enter 2nd value: 6
# The sum of 5 & 6 is 11.

# %%
width = float(input("Enter Rectangle width: "))
length = float(input("Enter Rectangle length: "))
area = width * length
print(f"The Area of Rectangle is {area}.")
# Out:
# Enter Rectangle width: 6
# Enter Rectangle length: 8
# The Area of Rectangle is 48.0.

# %%
a = 14
b = 3
c = a / b
d = a // b
e = a % b
f = a ** b
print(c)
print(d)
print(e)
print(f)
# Out:
# 4.666666666666667
# 4
# 2
# 2744

# %%
print("Hello\nWorld")
# Out:
# Hello
# World

# %%
print("Hello\tWorld")
# Out:
# Hello	World

# %%
print("Hell o\bWorld")
# Out:
# World

# %%
print("Hello \\ World")
# Out:
# Hello \ World

# %%
print("Hello \ World")
# Out:
# Hello \ World
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# /tmp/ipython-input-945597099.py:1: SyntaxWarning: invalid escape sequence '\ '
#   print("Hello \ World")

# %%
a += 1 # a = a + 1
print(a)
# Out:
# 16
