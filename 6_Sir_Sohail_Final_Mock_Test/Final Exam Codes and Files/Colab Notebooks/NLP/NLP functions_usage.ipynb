# %%
import NLP_functions as NLP

# %%
NLP.lower_case("ABC")
# Out:
# 'abc'

# %%
NLP.html_remover("<h1> Natural Language Processing</h1>")
# Out:
# ' Natural Language Processing'

# %%
NLP.remove_punctuation("$%^&**((#!@#@3))")
# Out:
# '3'

# %%
NLP.remove_stopwords("This is a sample sentence and we are going to remove the stopwords.", "english")
# Out:
# 'sample sentence going remove stopwords.'
