# %%
FileNm = "pyFile.txt"
File = open(FileNm, "w+")

# %% [markdown]
#  Get File Info

# %%
print("Name of the file: ", File.name)
# Out:
# Name of the file:  pyFile.txt

# %%
print("Closed or not: ", File.closed)
# Out:
# Closed or not:  False

# %%
print("Opening mode: ", File.mode)
# Out:
# Opening mode:  a

# %%
File.close()
print("Closed or not : ", File.closed)
# Out:
# Closed or not :  True

# %%
File = open(FileNm, "w")
File.write("Python: Write text to file " + "\n")
File.close()

# %%
File = open(FileNm, "r")
Str = File.read()
Str
# Out:
# 'Python: Write text to file \n'

# %%
File = open(FileNm, "w")
File.write("Python: Write text to file ")
File.close()

# %%
File = open(FileNm, "r")
Str = File.read()
Str
# Out:
# 'Python: Write text to file '

# %%
File = open(FileNm, "a")
Str = File.write("Python: 2nd line to the FIle " + "\n")
print(Str)
# Out:
# 30
