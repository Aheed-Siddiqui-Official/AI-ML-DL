# %%
import re
pttrn = "\d\d\d"
stmt = "python example: regx123 e.g"
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_441/1556114260.py:2: SyntaxWarning: invalid escape sequence '\d'
#   pttrn = "\d\d\d"

# %%
pattern.found(pttrn, stmt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_441/513718489.py in <cell line: 0>()
# ----> 1 pattern.found(pttrn, stmt)
#
# NameError: name 'pattern' is not defined

# %%
ptrn = "on+"
output = re.search(ptrn, stmt)
if output:
  print("pattern found")
else:
  print("Not found")
# Out:
# pattern found

# %%
# Out:
# pattern found:  on
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# /tmp/ipykernel_441/1699869498.py:1: SyntaxWarning: invalid escape sequence '\w'
#   ptrn = "^p\w+"

# %%
stmt2 = "My email addess is aliyan.ali"

# %%
ptrn = "\w+\.\w+@\w.\w+"
output = re.search(ptrn, stmt2)
if output:
  print("pattern found", output.group())
else:
  print("not found")
# Out:
# not found
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# /tmp/ipykernel_441/2454971045.py:1: SyntaxWarning: invalid escape sequence '\w'
#   ptrn = "\w+\.\w+@\w.\w+"
