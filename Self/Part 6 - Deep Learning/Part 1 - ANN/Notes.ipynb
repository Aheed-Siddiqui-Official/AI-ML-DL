# %% [markdown]
# # Deep Learning

# %% [markdown]
# It built layers of tiny switches(artificial neurons) inside a computer.
#
# Difference bertween ML vs DL is :
#
# ML is teaching a kid with rules(data) and hints(features)
#
# DL is like giving the kid a lot of fruits without telling the rules.
#
# ML : We choose the features model learns the rules
#
# DL : Model learns both the features and the rules
#
# DL works on big data large amount of data
#
# GPUs TPUs getting advanced
#
# Automatic feature learning
#
# Better performance in accuracy
#
# Versatality across domains gpt, face, self-driving cars, netflix recommendations, medical image analysis
#
# Research Breakthroughs => RNN, CNN, LSTM

# %% [markdown]
# ## Perceptron
#
# The perceptron is the simpliest type of artificial neuron, introduced by Frank Rosenblatt in 1958. It is the foundation of neural network and DL.
#
# It mimics how a biological neuron works taking inputs, processing them, and giving an output.
#
# Table ---> Age   Cholestrol   BP   Heart-Disease
#            28      150        110      1
#            36      120        90       0
#            42      180        60       1
#
# ### Logistic Regression
#
# ##### Step 1 => y = mx + b => h0(x) = 0o + 01x1
#
# h0(x) => 0o + 01x1 + 02x2 + 03x3
#
# If we plot points the line becomes straight
#
# ##### Step 2 => Then we apply sigmoid activation function for smooth curve   => 1/1+e^-z => z => (0o + 01x1 + 02x2 + 03x3)
#
# Then we get a squashed graph
#
# ##### Step 3 => After that log loss function applies for more accuracy
#
# Then we get to know what loss on what values
#
# ##### Step 4 => Then to reduce the loss we use gradient descent optimizer
#
# we find the lowest minima point
#
# ### Then Frank Rosenblatt in 1958 decided to do this work with neural networks Input Neuron and Output Neuron to do all of this using percetron
#
# Lets create three input layers (neurons) -> one output (neurons)
#
# x1 ->
#
# x2 ->         x4 (output neuron) (bias)
#
# x3 ->
#
# we connected all using weights and bias
#
# Formula Became => x1w1 + x2w2 + x3w3 + bias (looks like logistic regression formula)
#
# In neural network we used weights in place of 0
#
# We constantly changed 0 value we change weights values here this is also called
#
# ##### Forward Propagation
#
# We apply then Sigmoid Activation Function => 1 / 1+2^-z
#
# If we put a hidden layer between input and output layer that forms a neural network also called ANN
#
# ## Limitations of Perceptron
#
# Use a step activation function classify on 0 or 1 people cant use it for continous performance

# %% [markdown]
# ## ANN (Artificial Neural Network)
#
# x1
#
#        x
#
# x2             x
#
#        x
#
# x3
#
# All connected
#
# Input layer => hidden layer => output layer
#
# ## Forward Propagation
#
# x1    x2    x3     y
# 2.0   1.0   3.0    1
#
# x1(w1)
#
#         (w6)x(w4)
#
# x2(w2)               x
#
#         (w7)x(w5)
#
# x3(w3)
#
# weights decide your actions like a bottle hot or cold
#
# assign a seperate weight to a single neuron
#
# hidden connected neurons are assigned weights, hidden output neurons have bias
#
# assigning values e.g in (image) weights and biases :-
#
# 2.0
#
#
#
# 1.0
#
#
#
# 3.0
#
# weighted sum :
#
# n1 = (x1w1) + (x2w2) + (x3w3) + b
#
#    = 2.0(0.5) + 1.0(0.2) + 3.0(0.1) + 0.1
#
#    = 1.6
#
# Using sigmoid activation function for binary classification
#
#    = 1/1+e^-z => 0.8320 (Single Neuron Result)
#
# For output layer neuron
#
# = 0.8320(1.2) + 0.8176(-0.7) + 0.05
#
# = 0.4761
#
# Sigmoid Activation
#
# = 0.6168 => 1   (if val > 0.5 = 1 || val < 0.5 = 0)
#
# The above whole calculation is called forward propagation
#
# To improve results we update the weights by
#
# ## Backward propagation
#
# Important things
#
# 1) Activation Function
# 2) Loss Function
# 3) Optimizers
#
# Loss function and optimizers are used in Backward Propagation
#
# ##### When we did forward propagation we used an activation function that was sigmoid activation function so we predicted and calculated the result now when we will do backward propagation well calculate loss too relu gradient descent are type of optimizers.

# %% [markdown]
# ## Backward Propagation

# %% [markdown]
# e.g. = y = 0.6168 we can also say y = 1
#
# we calculated loss using mean squared error and cost function in linear regression and used log loss function in logistic regression
#
# To calculate loss well be using log loss formulae => [y * log (y^) + (1-y) * log (1-y^)]
#
# => 0.494 loss calculated
#
# Now we want to minimize reduce this loss using backward propagation we will go backward and adjust the weights
#
# ### Weight Updation Formulae
#
# w(new) = w(old) - n (derivative Loss / derivative w(old))
#
# if you want to update weight 7 you'll use chain rule
#
# w7(new) = w7(old) - n [(derivative Loss/derivative O3) * (derivative O3/derivative w7(old))]
#
# n = learning rate
#
# chain rule backward propagation starts with your last node
#
# we calculate each and every weight in backward propagation
#
# the flow is we do one time forward propagation => then we get a loss => we use that loss => find derivatives => update all weights
#
# ### Using an Optimizer e.g: Gradient Descent
#
# we used an activation function sigmoid => we get a result => then calculated loss using that result => then updated weights using that loss
#
# w1, w2, w3, w4, w5 => 0.432 => loss
#
# imporved version after backward propagation => 0.349
#
# then if we are not satisfied by the results we use multiple forwards and multiple backwards propagation and for the limit we use optimizers like gradient descent
#
# After this we use optimizers like gradient descent
#
# In gradient descent we hunt for global minima point
#
# we stop loss calculation when we reach least loss point
#
# This is called ANN
#
# #### One forward and one backward propagation is called Epoch
#
# we can do multiple times epochs during our training

# %% [markdown]
# ## Activation Functions

# %% [markdown]
# ### Vanishing Gradient Problem
#
# ### 1) Sigmoid Activation = 1/1+e^-z
#
# Vanishing gradient problem we dont use in regression tasks we avoid
#
# We can use it in churn prediction
#
# The vanishing gradient problem happens during backpropagation when gradients (the small updates we calculate to adjust weights) become so tiny that the earlier layers of a deep neural network stop learning.
#
# In other words:
#
# When training deep networks, gradients are multiplied layer by layer.
#
# If these gradients are very small (< 1), multiplying them across many layers makes them shrink toward zero.
#
# This means the first few layers (closer to the input) never get updated properly, so the network fails to learn important low-level features.
#
# Vanishing gradient is like when a image evolves to multiple steps/stages
#
# The result reduces in backward propagation epochs and the resultant comes near to 0 always and the range reduces and becomes small

# %% [markdown]
# ## Types of Activation Functions

# %% [markdown]
# ### 1) Linear Activation Function
#
# no squash direct results plotted like linear regression
#
# f(x) = x
#
# output same as input the neuron doesnt transform data it passes as it is
#
# it is used in regression tasks like predicting salary, house, price, temperature etc
#
# it is used in output layer of neural network because we dont want to restrict between 0-1
#
# Limitations:
#
# if we use it in all layers it just become a linear model like ML, we dont use it in hidden layers just output or input layer
#
# dont capture somplex non-linear patterns in data
#
# ### 2) Sigmiod Activation Function
#
# The sigmoid function is an S-shaped curve that squashes any real number into a range between 0 and 1.
#
# So no matter how large or small the input, the output will always stay between 0 and 1.
#
# Where do we use it?
#
# In binary classification problems (e.g., predicting yes/no, disease/no disease, spam/not spam).
# Usually in the output layer when you want a probability as the output.
#
# Example:
# If the sigmoid outputs 0.85, you can interpret it as 85% chance of having heart disease.
#
# Limitations
#
# Vanishing gradient problem: for very large or very small inputs, the gradient becomes almost 0, which slows learning.
#
# Not used in hidden layers much nowadays (ReLU is preferred).
#
# ### 3) Tanh Activation Function
#
# The tanh function (short for hyperbolic tangent) is another squashing function like sigmoid, but instead of squeezing values into 0 to 1, it squeezes them into -1 to +1.
#
# Where do we use it?
#
# • Often used in hidden layers of neural network
#
# Useful when data has both positive and negative values because it centres the output around 0 (unlike sigmoid which is centred at 0.5)
#
# Advantages
#
# Outputs are zero-centered (good for optimization).
#
# Stronger gradients than sigmoid in the range (−1,1), so learning can be faster.
#
# Limitations
#
# Still suffers from the vanishing gradient problem when inputs are very large (positive or negative).
#
# That’s why in modern deep learning, ReLU is more common in hidden layers.
#
# ### 4) ReLU Activation Function
#
# ReLU stands for Rectified Linear Unit.
#
# Linear said the value that is coming just pass it but relu says if +ve value pass it if -ve pass 0.
#
# That means:
#
# IF input x < 0 -> output = 0
#
# if input x > 0 -> output = x
#
# So it either passes positive values as they are or blocks negative values by turning them into 0.
#
# Where do we use it?
#
# • Hidden layers of almost all modern deep neural networks.
#
# • Works really well in CNNs (Convolutional Neural Networks), image recognition, NLP, and many more tasks.
#
# Advantages
#
# • Very fast and simple to compute.
#
# • Helps avoid vanishing gradient problem (better than sigmoid/tanh).
#
# • Makes training deep networks much faster.
#
# Limitations
#
# • Dying ReLU problem: sometimes neurons get stuck at 0 forever if weights update badly.
#
# • Not smooth at 0 (not differentiable there, but still works fine in practice).
#
# We make a neuron dead when 0 comes
#
# ### 5) Leaky ReLU Activation Function
#
# Instead of giving 0 for negative inputs, it gives a tiny negative value (like 0.01 × input).
#
# This way, the neuron is never completely dead.
#
# f(x) = x if x > 0
# 0.01x if x<=0
#
# Advantages of Leaky ReLU
#
# Fixes “Dead Neuron” Problem
#
# ◦ In normal ReLU, if inputs go negative, the output is always negative neuronsays 0, and sometimes the neuron stops learning permanently (dead neuron).
#
# ◦ Leaky ReLU solves this by allowing a small negative slope, so neurons still update weights.
#
# Computationally Simple
#
# ◦ Just like ReLU, the function is very easy to compute (no heavy math like exponentials in Sigmoid/Tanh).
#
# Better Gradient Flow
#
# ◦ Since even negative inputs have a small gradient (e.g., 0.01), the network can continue learning, reducing the vanishing gradient issue.
#
# Works Well in Deep Networks
#
# ◦ Especially useful in deep neural networks where ReLU may suffer from many dead neurons.
#
# Limitations: small negative slope may bias results, slope value needs tuning
#
# ### 6) PReLU Activation Function
#
# PReLU (Parametric Rectified Linear Unit) is an improved version of Leaky ReLU.
# In Leaky ReLU, the slope for negative values (like 0.01) is fixed by us. But in PReLU,
# that slope is learned automatically by the model during training. This makes it more
# flexible and adaptive.
#
# The formula is same as Leaky relu
#
# Intuition (Easy Way)
#
# ReLU: Negative values are killed (output = 0).
#
# Leaky ReLU: Negative values are given a tiny leak (e.g., 0.01x).
#
# PReLU: Instead of fixing that leak, the model says “I’ll learn the best leak slope
# myself.”
#
# Advantages
#
# 1. Fixes dead neurons (like Leaky ReLU).
# 2. Adaptive – slope is learned, not fixed.
# 3. Better accuracy – often improves CNNs and deep networks.
#
# Limitations
#
# 1. Extra parameters – slope a adds more trainable values.
# 2. Risk of overfitting if dataset is small.
# 3. Slightly more complex than plain ReLU.
#
# ### 7) Swish Activation Function
#
# Swish is a smooth, non-linear activation function introduced by Google researchers.
#
# Where σ(x) is the sigmoid function
# so basically: Swish = X * Sigmoid(x)
#
# Intuition (Easy Way)
#
# Think of it as ReLU but smoother.
#
# For large positive inputs → output ≈ input (like ReLU).
#
# For large negative inputs → output is small but not strictly zero (like
# Leaky ReLU).
#
# Around zero → the curve is smooth, not sharp like ReLU.
#
# This smoothness often makes training deep networks easier.
#
# Advantages
#
# 1. Smooth curve → better gradient flow, avoids sharp jumps like ReLU.
# 2. Non-monotonic → can adapt better to complex patterns.
# 3. Works well in deep networks (often improves accuracy over ReLU).
#
# Limitations
#
# 1. More computation (needs sigmoid).
# 2. Not always better than ReLU (depends on problem).
# 3. Slight risk of slower training compared to simple ReLU.
#
# ### Usage of Activation Function
#
# 0
#
#     0
#
#         0
#
# 0            0
#
#         0
#
#     0
#
# 0
#
# All nodes connected
#
# Layer 1 No Activation Functions
#
# Layer 2 Relu - Leaky Relu - Prelu for curves bends, hidden layers
#
# Layer 3 Relu - Leaky Relu - Prelu for curves bends, hidden layers
#
# Layer 4 - In output layers we have dependencies so we can use linear function, sigmoid activation function or multi class classification, soft max function

# %% [markdown]
# # Loss Functions

# %% [markdown]
# There are two types of problems when dealing with ML DL regression and classification and loss functions vary on this
#
# Regression => MSE(Mean Squared Error), MAE(Mean Absolute Error), Huber Loss, MSLE(Mean Squared Logrithimic Error)
#
# Classification => Binary Cross Entropy, Classification Cross Entropy
#
# ## Regression
#
# ### MSE (Mean Squared Error)
#
# loss or output - original data points
#
# #### MSE = 1/2 (y^-y)^2
#
# In ML we used cost function for finding errors, they are almost same but batch size difference
#
# If the batch size is above 1 well use cost function instead of MSE
#
# If we have 100 rows and 100 epochs wo well perfrom weights changing and perceptron updation 10000 times and 100 rows dont remains same all the time
#
# Thats why we use batch size
#
# Batch size tells if you have 100 rows and batch size = 10 so at a time 10 rows will go forward
#
# Then the formula becomes :
#
# #### Cost Function = 1/2 (n)E(i=1) (y^-y)^2
#
# So if you have 16 rows and you set batch size = 4 so at a time 4 rows will go
#
# #### Pros
#
# Very commom easy to calculate mostly used
#
# Penalizes the big errors e.g. if we have a loss $5000 and model predicted error $100k dollars so we are away $95000 so if we square that loss
#
# #### Cons
#
# Mean Squared Error is very sensative to outliers changes the graph based on big errors
#
# Used in basic taks where big errors like house price prediction etc
#
# ### MAE (Mean Absolute Error)
#
# #### MAE = 1/N (n)E(i=1) (y^-y)
#
# #### Pros
#
# More robust to outliers
#
# Outliers doenst matter for it
#
# Each error contributes equally
#
# #### Cons
#
# Doesn't punish large errors
#
# ### Huber Loss
#
# Huber loss says ill use MAE and MSE both e.g. if you have small erros ill use MSE and if large error MAE
#
# Someone created a function that deals with both big and small error
#
# #### Cons
#
# The only con is it takes hyperparemeters so you have to set the limit that after how many time you have to set the small and large errors limit
#
# ### MSLE
#
# Mean squered error log
#
# If we use log and have -ve values so it turn value 0 so avoid at this condition
#
# Used in growth values like user, population, financial
#
# Least used not common yearly growth like that
#
# ## Classification
#
# apply the loss functions based on the conditions refer the notes
#
# ### Binary Cross Entropy
#
# when binary 0, 1 prediction multiple inputs but single neuron for output
#
# last layer in activation function should be sigmoid activation function because it gives value between 0 an 1
#
# you use binary cross entorpy as loss function if you use sigmoid activation function in the last layer through this you get the value 0 and 1
#
# ### Categorical Cross Entropy
#
# One hot encoding classifies into 1 ans 0
#
# output layer has 3 things cat dog horse
#
# Now well use categorical cross entropy no need to use sigmoid activation function well use Softmax activation function
#
# Well also change neuron from 1 to 3 at last layer and also activation function to softmax
#
# ### Sparse Categorical Cross Entropy
#
# Not using one hot encoding here
#
# we do numbering of data here
#
# we need 6 output layer neurons accordint to the categorical distribution
#
# here we use sparse categorical cross entropy
